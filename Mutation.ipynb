# %%
import utils
# Out:
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.conda.ubuntu.cxx11thread.serialization.Ubuntu.python313.Release 2026.26+release.f8a8eab4344af49c25e1e5db84ce25fec05eea27 2026-06-25T18:00:21] retrieved from: http://www.pyrosetta.org

# %%
utils.insert_mutation('pdb_files/7K18_relax.pdb', 'GTVLSDIIQKYFF', 'KVCGCDLAQGGFF')
# Out:
# --------------------------------------------------
# TASK COMPLETE
# Successfully mutated GLY at position 955 to LYS
# Orginal Energy 7162.306611259988; New energy: 7110.347052236754
# --------------------------------------------------
